# %% [markdown]
# # **Variables**

# %%
a = 10

print(a)

print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b = 10.5

print(type(b))
# Out:
# <class 'float'>

# %%
a = b

print(a)
print(type(a))
# Out:
# 10.5
# <class 'float'>

# %%
name = "phitron"

print(type(name))
# Out:
# <class 'str'>

# %%
data = input()

print(data)
print(type(data))
# Out:
# hamim
# hamim
# <class 'str'>

# %%
a = input()
print(type(a))
a = int(a)
print(a)
print(type(a))
# Out:
# 11
# <class 'str'>
# 11
# <class 'int'>

# %%
row_number = input()

print(row_number,type(row_number))

numbers = row_number.split()

a = int(numbers[0])
print(a)
print(type(a))


b = int(numbers[1])

print(b)
print(type(b))
print(numbers)
print(type(numbers))
# Out:
# 10 20 30
# 10 20 30 <class 'str'>
# 10
# <class 'int'>
# 20
# <class 'int'>
# ['10', '20', '30']
# <class 'list'>

# %% [markdown]
# # **Conditional Statements**

# %%
import torch
import torch.nn as nn

# 1. New Input: Let's assume these 4 features represent
image_features = torch.tensor([[0.15, 0.85, 0.25, 0.70]])

# 2. Updated Network Architecture
model = nn.Sequential(
    nn.Linear(4, 12),
    nn.ReLU(),
    nn.Linear(12, 1),
    nn.Sigmoid()
)

# 3. Get prediction
# Note: We use torch.no_grad() because we aren't training right now
with torch.no_grad():
    prediction = model(image_features)


prob = prediction.item()
print(f"Probability of being a Dog: {prob:.4f}")

# 4. Interpret the result

if prob==0.5:
  print("Couldn't classify the image")
elif prob>0.5:
  print("Cat")
else:
  print("Dog")
# Out:
# Probability of being a Dog: 0.4998
# Dog

# %% [markdown]
# # **Loop**

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

data = load_breast_cancer()
X, y = data.data, data.target


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

k_values = range(1, 51)
accuracies = []

print(f"{'K Value'} | {'Test Accuracy'}")


for k in k_values:
    # Initialize and fit
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)

    # Calculate accuracy
    score = knn.score(X_test, y_test)

    print(f"k = {k} | {score:.4f}")
# Out:
# K Value | Test Accuracy
# k = 1 | 0.9357
# k = 2 | 0.9298
# k = 3 | 0.9415
# k = 4 | 0.9474
# k = 5 | 0.9591
# k = 6 | 0.9591
# k = 7 | 0.9649
# k = 8 | 0.9649
# k = 9 | 0.9708
# k = 10 | 0.9825
# k = 11 | 0.9766
# k = 12 | 0.9766
# k = 13 | 0.9649
# k = 14 | 0.9649
# k = 15 | 0.9649
# k = 16 | 0.9649
# k = 17 | 0.9649
# k = 18 | 0.9649
# k = 19 | 0.9591
# k = 20 | 0.9649
# k = 21 | 0.9532
# k = 22 | 0.9532
# k = 23 | 0.9532
# k = 24 | 0.9532
# k = 25 | 0.9474
# k = 26 | 0.9532
# k = 27 | 0.9474
# k = 28 | 0.9532
# k = 29 | 0.9474
# k = 30 | 0.9474
# k = 31 | 0.9474
# k = 32 | 0.9474
# k = 33 | 0.9357
# k = 34 | 0.9474
# k = 35 | 0.9415
# k = 36 | 0.9415
# k = 37 | 0.9415
# k = 38 | 0.9415
# k = 39 | 0.9415
# k = 40 | 0.9474
# k = 41 | 0.9415
# k = 42 | 0.9415
# k = 43 | 0.9357
# k = 44 | 0.9415
# k = 45 | 0.9357
# k = 46 | 0.9357
# k = 47 | 0.9357
# k = 48 | 0.9415
# k = 49 | 0.9357
# k = 50 | 0.9474

# %% [markdown]
# # **List**

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

data = load_breast_cancer()
X, y = data.data, data.target


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

k_values = range(1, 51)
accuracies = []


for k in k_values:
    # Initialize and fit
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)

    # Calculate accuracy
    score = knn.score(X_test, y_test)
    accuracies.append(score)

print(accuracies)
print(len(accuracies))
mx_acc=max(accuracies)
print(mx_acc)

best_k_index=accuracies.index(mx_acc)
print(best_k_index)

best_k=k_values[best_k_index]
print(best_k)
# Out:
# [0.935672514619883, 0.9298245614035088, 0.9415204678362573, 0.9473684210526315, 0.9590643274853801, 0.9590643274853801, 0.9649122807017544, 0.9649122807017544, 0.9707602339181286, 0.9824561403508771, 0.9766081871345029, 0.9766081871345029, 0.9649122807017544, 0.9649122807017544, 0.9649122807017544, 0.9649122807017544, 0.9649122807017544, 0.9649122807017544, 0.9590643274853801, 0.9649122807017544, 0.9532163742690059, 0.9532163742690059, 0.9532163742690059, 0.9532163742690059, 0.9473684210526315, 0.9532163742690059, 0.9473684210526315, 0.9532163742690059, 0.9473684210526315, 0.9473684210526315, 0.9473684210526315, 0.9473684210526315, 0.935672514619883, 0.9473684210526315, 0.9415204678362573, 0.9415204678362573, 0.9415204678362573, 0.9415204678362573, 0.9415204678362573, 0.9473684210526315, 0.9415204678362573, 0.9415204678362573, 0.935672514619883, 0.9415204678362573, 0.935672514619883, 0.935672514619883, 0.935672514619883, 0.9415204678362573, 0.935672514619883, 0.9473684210526315]
# 50
# 0.9824561403508771
# 9
# 10

# %% [markdown]
# # **Dictionary**

# %%
model_configs = {
    "KNN": {
        "model": KNeighborsClassifier,
        "params": [3, 5, 11]
    },
    "RandomForest": {
        "model": RandomForestClassifier,
        "params": [10, 50, 100]
    }
}

# %%
import pandas as pd

ml_results = {
    "Model_Name": ["KNN", "RandomForest", "LogisticReg"],
    "Best_K": [5, 100, None],
    "Accuracy": [0.942, 0.965, 0.910],
    "Train_Time_Sec": [0.02, 1.45, 0.08]
}


df = pd.DataFrame(ml_results)

df.head()
# Out:
#      Model_Name  Best_K  Accuracy  Train_Time_Sec
# 0           KNN     5.0     0.942            0.02
# 1  RandomForest   100.0     0.965            1.45
# 2   LogisticReg     NaN     0.910            0.08

# %%
{'a': 1, 'b': 2}.keys()
# Out:
# dict_keys(['a', 'b'])
