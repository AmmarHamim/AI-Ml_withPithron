# %% [markdown]
# # Problem_01

# %%
def introduce(name,age):
  print(f"My name is {name} and i am {age} years old.")

introduce("Hamim",22)
# Out:
# My name is Hamim and i am 22 years old.

# %% [markdown]
# # Problem_02

# %%
def batch_generator(data,batch_size):
  for i in range(0,len(data),batch_size):
    yield data[i:i+batch_size]


data=[1,2,3,4,5,6,7,8]
batch_size=3

for batch in batch_generator(data,batch_size):
  print(batch)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8]

# %% [markdown]
# # Problem_03

# %%
lst=[1,2,3,4]
res= map(lambda x:x**2,lst)
print(type(res))
print(list(res))
# Out:
# <class 'map'>
# [1, 4, 9, 16]

# %% [markdown]
# # Problem_04

# %%
def power(base,exp=2):
  return base**exp

print(power(2,8))
print(power(3,3))
print(power(3))
# Out:
# 256
# 27
# 9

# %% [markdown]
# # Problem_05

# %%
nums = [1, 2, 3, 4, 5, 6]
evens=filter(lambda x:x%2==0,nums)
sq_evens=map(lambda x:x**2,evens)
print(list(sq_evens))
# Out:
# [4, 16, 36]

# %%
# result = list(map(lambda x: x**2, filter(lambda x: x % 2 == 0, nums)))
result=(map(lambda x:x**2,filter(lambda x:x%2==0,nums)))
print(list(result))
# Out:
# [4, 16, 36]
