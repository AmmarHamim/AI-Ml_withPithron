# %% [markdown]
# ## 1.Variables and Data Type

# %%
age=55
print(age)

# %%
name="Hamim"
print(name)

# %%
age=33
name='jamal'
marks=55.5
passed=True
# age=55.5

print(type(age),type(name),type(marks),type(passed))

# %% [markdown]
# ## 2.Taking Input in Python

# %%
name=input("Enter your name: ")
print(name)

# %%
age=input("Age??")
print(age,type(age))
# Out:
#  <class 'str'>

# %%
age=input("Age??")
age=int(age) ##converted to int
print(age,type(age))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 age=input("Age??")
# ----> 2 age=int(age) ##converted to int
#       3 print(age,type(age))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
height=float(input("Height?"))
print(height,type(height))

# %% [markdown]
# ## 3.Operators in Python

# %% [markdown]
# ##### 3.1 Arithmetic Operators

# %%
x = 10 ; y = 3 

sum = x + y # summation 
sub = x - y # subtraction
mult = x * y # multiplication
div = round(x / y , 2) # division 

rem = x % y # remainder 

print(sum , sub , mult, div , rem)

# %% [markdown]
# ##### 3.2 Comparison (Relational) Operators

# %%
x = 10 ; y = 3 

greater_than = x > y 

greater_than_equal = (10 >= 11)

print(greater_than , greater_than_equal)


less_than = x < y 

less_than_equal = (10 <= 10)

print(less_than , less_than_equal)



equal =  x==y

print(equal)


not_equal = x != y

print(not_equal)

# %% [markdown]
# ##### 3.3 Logical Operators

# %%
x=10;y=20;z=30
result=(z>y) and (y>x)
print(result)

# %%
x = True
y = False

print(x and y)  # False
print(x or y)   # True
print(not x)    # False

# %% [markdown]
# ##### 3.3.1 Precedence and Associavity

# %%
eq = 10 + 10/2 - 5*2
print(eq)

eq = (10+10)/2 - 5*2 

print(eq)
# Out:
# 5.0
# 0.0

# %% [markdown]
# ## 4.Problem Solving

# %% [markdown]
# ##### 4.1 Digit Summation

# %%
n,m=map(int,input().split())
res= n%10 + m%10

print(res)
# Out:
# 2

# %% [markdown]
# ##### 4.2 Max Min

# %%
a,b,c=map(int,input().split())
m=max(a,b,c)
mm=min(a,b,c)

print(mm, m)
# Out:
# -2 55

# %% [markdown]
# ##### 4.3 Even, Odd, Positive and Negative

# %%
# n=int(input())
num=list(map(int,input().split()))
n=len(num)

pos=neg=even=odd=0
for x in num:
    if(x>0 and x%2==0):
        pos+=1
        even+=1
    elif(x>0 and x%2==1):
        pos+=1
        odd+=1
    elif(x<0 and x%2==0):
        neg+=1
        even+=1
    elif(x<0 and x%2==1):
        neg+=1
        odd+=1

print("Even: ",even)
print("Odd: ",odd)
print("Positive: ",pos)
print("Negative: ",neg)
# Out:
# Even:  2
# Odd:  2
# Positive:  1
# Negative:  3
