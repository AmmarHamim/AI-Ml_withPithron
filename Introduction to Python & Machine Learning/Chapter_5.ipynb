# %% [markdown]
# # Tuples

# %%
tup=(10,20,30,"str",False)
print(type(tup),tup)
print(tup)

lst = [10,20,30]
tup1 = tuple(lst)
print(type(tup1),tup1)
# Out:
# <class 'tuple'> (10, 20, 30, 'str', False)
# (10, 20, 30, 'str', False)
# <class 'tuple'> (10, 20, 30)

# %%
# Access 
tup = ( 10 , 20 , 30 , 10.5 , "str" , False )

#index 
print(tup[4]) 
new_tup = tup[0:3]
print(new_tup)
# Out:
# str
# (10, 20, 30)

# %%
lst = [ 10 , 20 , 30 , 40 ] 
lst.append(60)
lst[1] = 100
print(lst)

# immutable
tup= ( 10 , 20 , 30 , 40 ) 
tup[1]= 100 
print(tup)
# Out:
# [10, 100, 30, 40, 60]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       6 # immutable
#       7 tup= ( 10 , 20 , 30 , 40 )
# ----> 8 tup[1]= 100
#       9 print(tup)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuple method 
tup= ( 10 , 20 , 30 , 40 , 10 , 20 , 30 ,10 )

print(tup.count(10))
print(tup.index(40))
# Out:
# 3
# 3

# %%
single_tup=(10,)
print(type(single_tup),single_tup)
# Out:
# <class 'tuple'> (10,)

# %% [markdown]
# ## Sets

# %%
A = { 1, 2 , 3,1,3 } 

print(type(A) , A )
# Out:
# <class 'set'> {1, 2, 3}

# %%
B=[]
print(type(B))

C=()
print(type(C))

D={}
print(type(D))

S=set()
print(type(S))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>

# %%
#accessing 

S= { 1 ,2 ,3 , 4 ,1 ,2 } 

if (10 in S):
    print("3 is present")
else:
    print("not present")

sum =0 

for element in S:
    sum+= element 

print(sum)
# Out:
# not present
# 10

# %%
#mutable

s= {5, 1 , 2 ,4, 3} 

s.add(10) 
s.add(0)

print(s)

s.pop()
s.pop()
print(s)

s.remove(5) 

print(s)
# Out:
# {0, 1, 2, 3, 4, 5, 10}
# {2, 3, 4, 5, 10}
# {2, 3, 4, 10}

# %%
a = { 1, 2, 3 } 
b = {1, 2 , 5,6, 4 } 

print( a.union(b) )

print(a.intersection(b)) 

print(a.isdisjoint(b))

print(a.issubset(b))
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2}
# False
# False

# %% [markdown]
# # Dictionary

# %%
dic={}

print(type(dic))

dic={"Name":"Hamim","age":23,"height":5.7}
print(dic)
print(dic["age"])
print(dic.get("height"))

dic["Name"]="Ammar Hamim"
print(dic)
# Out:
# <class 'dict'>
# {'Name': 'Hamim', 'age': 23, 'height': 5.7}
# 23
# 5.7
# {'Name': 'Ammar Hamim', 'age': 23, 'height': 5.7}

# %%
#printing default values
print(dic) 

print(dic.get("math_marks"))
print(dic.get("math_marks",0))
# Out:
# {'Name': 'Ammar Hamim', 'age': 23, 'height': 5.7}
# None
# 0

# %%
#adding values
print(dic)
dic["math_marks"]=88
print(dic)

dic.update({"eng_marks":85})
print(dic)
# Out:
# {'Name': 'Ammar Hamim', 'age': 23, 'height': 5.7}
# {'Name': 'Ammar Hamim', 'age': 23, 'height': 5.7, 'math_marks': 88}
# {'Name': 'Ammar Hamim', 'age': 23, 'height': 5.7, 'math_marks': 88, 'eng_marks': 85}

# %%
#deleting
del dic["math_marks"]
print(dic)
# Out:
# {'Name': 'Ammar Hamim', 'age': 23, 'height': 5.7, 'eng_marks': 85}

# %%
#coping
dic2=dic.copy()
print(dic2)
# Out:
# {'Name': 'Ammar Hamim', 'age': 23, 'height': 5.7, 'eng_marks': 85}

# %%
keys=dic.keys()
print(keys)

values=dic.values()
print(values)

items=dic.items()
print(items)
# Out:
# dict_keys(['Name', 'age', 'height', 'eng_marks'])
# dict_values(['Ammar Hamim', 23, 5.7, 85])
# dict_items([('Name', 'Ammar Hamim'), ('age', 23), ('height', 5.7), ('eng_marks', 85)])

# %%
#keys must be immutable...str,tuple

test_dic={"hamim":23,(12,11):'haa'}
print(test_dic)
# Out:
# {'hamim': 23, (12, 11): 'haa'}

# %% [markdown]
# # Dictionary Comprehension

# %%
square={x:x**2 for x in range(10)}
print(square)

even_qube={x:x**3 for x in range(1,11) if x%2==0}
print(even_qube)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
# {2: 8, 4: 64, 6: 216, 8: 512, 10: 1000}

# %%
Co_ordinates = [(10,10.5),(20.5,192) , ( 101,102) ]
Locations =["dhaka" , "chattogram" , "sylhet"]

exact_loc={cor:loc for cor,loc in zip(Co_ordinates,Locations)}
print(exact_loc)
# Out:
# {(10, 10.5): 'dhaka', (20.5, 192): 'chattogram', (101, 102): 'sylhet'}

# %% [markdown]
# # Problem Solving with In Built Structures

# %% [markdown]
# ## 1. Given a list of numbers, make a list with unique values.

# %%
lst = [10 , 20 , 10 , 30 , 30 , 50 , 30 , 10 , 20 , 10 , 10 ]
unique_val=set(lst)
unique_val=list(unique_val)
print(type(unique_val))
print(unique_val)
# Out:
# <class 'list'>
# [10, 20, 50, 30]

# %% [markdown]
# ## 2. Given a string , print the frequency of the words

# %%
string = """data science machine learning data analysis machine 
learning statistics data models data training data validation features
features labels preprocessing data augmentation models data optimization 
gradient descent neural networks data tensors matrices visualization 
exploration pandas numpy matplotlib seaborn scikitlearn tensorflow pytorch 
deployment inference production monitoring reproducibility experiments results 
metrics accuracy precision recall f1 cross validation data machine
"""

words=string.split()
# print(words)

freq={}

for word in words:
    if word in freq:
        freq[word]+=1
    else:
        freq[word]=1

# print(freq)

for k,v in freq.items():
    print(f"Count of {k} is {v}")
# Out:
# Count of data is 9
# Count of science is 1
# Count of machine is 3
# Count of learning is 2
# Count of analysis is 1
# Count of statistics is 1
# Count of models is 2
# Count of training is 1
# Count of validation is 2
# Count of features is 2
# Count of labels is 1
# Count of preprocessing is 1
# Count of augmentation is 1
# Count of optimization is 1
# Count of gradient is 1
# Count of descent is 1
# Count of neural is 1
# Count of networks is 1
# Count of tensors is 1
# Count of matrices is 1
# Count of visualization is 1
# Count of exploration is 1
# Count of pandas is 1
# Count of numpy is 1
# Count of matplotlib is 1
# Count of seaborn is 1
# Count of scikitlearn is 1
# Count of tensorflow is 1
# Count of pytorch is 1
# Count of deployment is 1
# Count of inference is 1
# Count of production is 1
# Count of monitoring is 1
# Count of reproducibility is 1
# Count of experiments is 1
# Count of results is 1
# Count of metrics is 1
# Count of accuracy is 1
# Count of precision is 1
# Count of recall is 1
# Count of f1 is 1
# Count of cross is 1

# %% [markdown]
# ## Problem Links
# ## https://codeforces.com/group/MWSDmqGsZm/contest/219856/problem/J
# ## https://www.hackerrank.com/challenges/no-idea/
# ## https://www.hackerrank.com/challenges/python-tuples/

# %% [markdown]
# ## Count letters

# %%
strr=input()
# print(type(strr))
freqdic={}

for ch in strr:
    if ch in freqdic:
        freqdic[ch]+=1
    else:
        freqdic[ch]=1

# print(freqdic)
for k in sorted(freqdic):
    print(f"{k} : {freqdic[k]}")
# Out:
#  aaaccxxb
# a : 3
# b : 1
# c : 2
# x : 2

# %% [markdown]
# ## No Idea!

# %%
n,m=map(int,input().split())

arr=list(map(int,input().split()))
a=set(map(int,input().split()))
b=set(map(int,input().split()))

# print(arr)
# print(a)
# print(b)
happ=0
for x in arr:
    if x in a:
        happ+=1
    if x in b:
        happ-=1

print(happ)
# Out:
#  3 2
#  1 5 3
#  3 1
#  5 7
# 1

# %% [markdown]
# ## Tuples

# %%
n=int(input())
tup=tuple(map(int,input().split()))
# print(tup)

# hashed=hash(tup)
print(hash(tup))
# Out:
#  2
#  1 2
# -3550055125485641917
